# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# \begin {equation}
# E = \frac{hc}{\lambda}
# \end {equation}

# %% [markdown]
# $$F = G\frac{m_{1} m_{2}}{r^2}$$

# %% [markdown]
# $$\sin{2x} = 2\sin{x}\cos{x} = \frac{2\tan{x}}{1+\tan^2{x}}$$

# %% [markdown]
# $$\displaystyle\sum_{k=0}^{\infty} \frac{1}{4k^2 - 1} = \frac{1}{2}$$

# %% [markdown]
# $$\int_0^\pi \mathrm{e}^{ix}\, \mathrm{d}x = 2i$$

# %% [markdown]
# QUESTION 2.11

# %%
import math

x = 2
y = 3

phi = math.atan2(y,x)
print(phi)
# Out:
# 0.982793723247329

# %%
math.tan(phi)
# Out:
# 1.5

# %% [markdown]
# Question 2.12

# %%
from math import atan2, degrees

x=float(input("Enter the value of x:"))
y=float(input("Enter the value of y:"))

phi = atan2(y,x)

angle_deg = degrees(phi)

print("Angle in radians: ", phi)
print("Angle in degrees: ", angle_deg)

if x>0 and y>0:
    print("Quadrant 1")

elif x<0 and y>0:
    print("Quadrant 2")

elif x<0 and y<0:
    print("Quadrant 3")

elif x>0 and y<0:
    print("Quadrant 4")

else:
    print("Point lies on an axis")
# Out:
# Enter the value of x: 5
# Enter the value of y: 3
# Angle in radians:  0.5404195002705842
# Angle in degrees:  30.96375653207352
# Quadrant 1

# %% [markdown]
# Question 2.14

# %%
X = [1.36, 1.46, 1.41, 2.12, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18]
X.append(0.51)
X.remove(2.12)
print(X)
print(f"Index of 1.46 is: {X.index(1.46)}")
print(f"Value at index 6 is:{X[6]}")
indices = slice(2,-2,2)
X_slice = X[indices]
print(f"X_slice = {X_slice}")
print(sum(X_slice))
# Out:
# [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# Index of 1.46 is: 1
# Value at index 6 is:1.97
# X_slice = [1.41, 0.98, 1.97]
# 4.359999999999999

# %% [markdown]
# Question 2.15

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
a = set(night1)
b = set(night2)
inter = a.intersection(b)
c = list(inter)
print(c)
X = 5 in a
Y = 5 in inter
print(X)
print(Y)
# Out:
# [0, 1, 2, 3, 4]
# True
# False

# %% [markdown]
# Question 2.19

# %%
import numpy
x = numpy.random.normal(0.0, 1.4, size=100000)
print(x)
a = x.std()
print(f"The standard devation is: {a}")
# Out:
# [ 2.28564638 -0.85605097  2.79501567 ...  2.42727154  0.42833349
#   1.28009413]
# The standard devation is: 1.4005143151235926

# %% [markdown]
# Question 2.21

# %%
a, b = 1, 2
for i in range(98):
    a, b = b, a+b
print(f" The 100th term is:{b}")
# Out:
#  The 100th term is:573147844013817084101

# %% [markdown]
# ![Screenshot_20260218_172009.png](attachment:Screenshot_20260218_172009.png)
