# %% [markdown]
# Answers for Week 1

# %% [markdown]
# Name: Stelios Bazigos
# Username: smbazigos
# Student s-number: S6064515
# Group: AS2

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7

# %%
number = 1
number *=2
number *=3
number *=4
number *=5
number *=6
print (number)
# Out:
# 720

# %%
import math

# %%
frequency = 2.42 * 10**28

h = 6.626 * 10**(-34)

Energy = frequency * h

print (Energy)
# Out:
# 1.6034919999999996e-05

# %%
import math

# %%
from scipy.constants import G

# %%
massm = 7.342 * 10**22
masse = 5.9722 * 10**24 
r = 385000600

# %%
Force = (G*massm*masse / r**2)

# %%
print (Force)
# Out:
# 1.974384051807571e+20

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143
